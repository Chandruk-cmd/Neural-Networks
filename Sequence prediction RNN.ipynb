# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset_train = pd.read_csv('input.csv')

# %%
dataset_train = pd.read_csv('input.csv')
x_train, y_train=dataset_train.iloc[:,0:3].values, dataset_train.iloc[:,3:].values
x_train,y_train=np.array(x_train), np.array(y_train)
x_train= np.reshape(x_train, (x_train.shape[0], x_train.shape[1],1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN

# %%
model = Sequential()
model.add(SimpleRNN(units = 150,return_sequences=True, input_shape = (3,1)))
model.add(SimpleRNN(units = 50))
model.add(Dense(units = 1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# simple_rnn (SimpleRNN)       (None, 3, 150)            22800
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 50)                10050
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# ...
# Total params: 32,901
# Trainable params: 32,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, epochs=1000)
predicted_number = model.predict(x_train)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0219
# Epoch 2/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0218
# Epoch 3/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0216
# Epoch 4/1000
# 1/1 [==============================] - 0s 999us/step - loss: 0.0215
# Epoch 5/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0213
# Epoch 6/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0212
# Epoch 7/1000
# 1/1 [==============================] - 0s 1000us/step - loss: 0.0210
# Epoch 8/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0209
# Epoch 9/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0208
# Epoch 10/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0206
# Epoch 11/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0205
# Epoch 12/1000
# ...

# %%
plt.plot(y_train, color='red', label='Real Next Number')
plt.plot(predicted_number, color='blue', label = 'Predicted Number')
plt.title('Numeric Series Prediction')
plt.xlabel('Time')
plt.ylabel('Next Number')
plt.legend()
